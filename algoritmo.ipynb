# %%
import pandas as pd
import seaborn as sns

# %%
reviews = pd.read_csv('sm.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ae26b5da1161> in <module>()
# ----> 1 reviews = pd.read_csv('sm.csv')
#
# NameError: name 'pd' is not defined

# %%
print(reviews.columns)

# %%
reviews.head()
# Out:
#    N�mero de caso        Tipo de caso  \
# 0          701506  Ruidos o Molestias
# 1          701505             Interno
# 2          701504             Interno
# 3          701503  Ruidos o Molestias
# 4          701502             Interno
#
#                                     Subtipo de casos  Estado  Subestado  \
# 0  Retiro de Consumidores de Alcohol en la v�a p�...     NaN        NaN
# 1                                          Operativo     NaN        NaN
# 2                                          Operativo     NaN        NaN
# 3                     Apoyo Diverso al Contribuyente     NaN        NaN
# 4                                          Operativo     NaN        NaN
#
#   Detalles de lugar y otros Fecha de notificaci�n          Unidad reportante  \
# 0                       NaN   31-01-2018 23:59:12  Ciudadan�a Distrital (10)
# 1                       NaN   31-01-2018 23:58:24  Ciudadan�a Distrital (10)
# ...

# %%
dummy=pd.get_dummies(reviews['Tipo de caso'])
data = pd.concat([reviews,dummy],axis=1)
print(data.head())
# Out:
#    N�mero de caso        Tipo de caso  \
# 0          701506  Ruidos o Molestias
# 1          701505             Interno
# 2          701504             Interno
# 3          701503  Ruidos o Molestias
# 4          701502             Interno
#
#                                     Subtipo de casos  Estado  Subestado  \
# 0  Retiro de Consumidores de Alcohol en la v�a p�...     NaN        NaN
# 1                                          Operativo     NaN        NaN
# 2                                          Operativo     NaN        NaN
# 3                     Apoyo Diverso al Contribuyente     NaN        NaN
# 4                                          Operativo     NaN        NaN
#
#   Detalles de lugar y otros Fecha de notificaci�n          Unidad reportante  \
# 0                       NaN   31-01-2018 23:59:12  Ciudadan�a Distrital (10)
# 1                       NaN   31-01-2018 23:58:24  Ciudadan�a Distrital (10)
# ...

# %%
sns.countplot(data['Fecha de notificaci�n'])

# %%
sns.kdeplot(reviews['Fecha de notificaci�n'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-6419c4b347c7> in <module>()
# ----> 1 sns.kdeplot(reviews['Fecha de notificaci�n'])
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     617         return ax
#     618
# --> 619     data = data.astype(np.float64)
#     620     if data2 is not None:
#     621         if isinstance(data2, list):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
# ...

# %%
reviews['Tipo de caso'].value_counts().sort_index().plot.bar(figsize=(12,6))

# %%
reviews['Situaci�n'].value_counts().sort_index().plot.bar(figsize=(12,6))

# %%
sns.distplot(data['Ruidos o Molestias'], bins=10, kde=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-b528299d1f33> in <module>()
# ----> 1 sns.distplot(data['Fecha de notificaci�n'], bins=10, kde=True)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     193             line, = ax.plot(0, a.mean())
#     194         else:
# --> 195             line, = ax.plot(a.mean(), 0)
#     196         color = line.get_color()
#     197         line.remove()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      85             ret = ret.dtype.type(ret / rcount)
#      86     else:
# ---> 87         ret = ret / rcount
#      88
# ...

# %%
sns.jointplot(x='Fecha de notificaci�n', y='Interno', data=data)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-1e6d4f03b27b> in <module>()
# ----> 1 sns.jointplot(x='Fecha de notificaci�n', y='Interno', data=data)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
# ...

# %%
sns.countplot(y="Tipo de caso", hue="Subtipo de casos", data=reviews, palette="Set3" )
